# %%
import pandas as pd

# %%
import plotly.express as px

# %%
df = pd.read_csv('C:/Users/xaidi/Documents/Machine-Learning-mtf-830-oct12/datasets/house_pricing.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#          City         Type  Beds  Baths  SquareFeet      Price
# 0  SACRAMENTO  Residential     2      1         836  138159.85
# 1  SACRAMENTO  Residential     3      1        1167  167541.46
# 2  SACRAMENTO  Residential     2      1         796  119095.12
# 3  SACRAMENTO  Residential     2      1         852  130904.95
# 4  SACRAMENTO  Residential     2      1         797  120266.19

# %%
df.tail()
# Out:
#                 City         Type  Beds  Baths  SquareFeet      Price
# 809       SACRAMENTO  Residential     4      3        2280  308248.47
# 810       SACRAMENTO  Residential     3      2        1477  212857.63
# 811   CITRUS HEIGHTS  Residential     3      2        1216  181746.98
# 812        ELK GROVE  Residential     4      2        1685  245385.59
# 813  EL DORADO HILLS  Residential     3      2        1362  263355.13

# %%
df.head(2)
# Out:
#          City         Type  Beds  Baths  SquareFeet      Price
# 0  SACRAMENTO  Residential     2      1         836  138159.85
# 1  SACRAMENTO  Residential     3      1        1167  167541.46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814 entries, 0 to 813
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        814 non-null    object
#  1   Type        814 non-null    object
#  2   Beds        814 non-null    int64
#  3   Baths       814 non-null    int64
#  4   SquareFeet  814 non-null    int64
#  5   Price       814 non-null    float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 38.3+ KB

# %%
df.describe(include='all')
# Out:
#               City         Type        Beds       Baths   SquareFeet  \
# count          814          814  814.000000  814.000000   814.000000
# unique          36            3         NaN         NaN          NaN
# top     SACRAMENTO  Residential         NaN         NaN          NaN
# freq           424          759         NaN         NaN          NaN
# mean           NaN          NaN    3.244472    1.960688  1591.146192
# std            NaN          NaN    0.852137    0.669804   663.841930
# min            NaN          NaN    1.000000    1.000000   484.000000
# 25%            NaN          NaN    3.000000    2.000000  1144.000000
# 50%            NaN          NaN    3.000000    2.000000  1418.500000
# 75%            NaN          NaN    4.000000    2.000000  1851.000000
# max            NaN          NaN    8.000000    5.000000  5822.000000
#
#                 Price
# count      814.000000
# unique            NaN
# top               NaN
# freq              NaN
# ...

# %%
df.head()
# Out:
#          City         Type  Beds  Baths  SquareFeet      Price
# 0  SACRAMENTO  Residential     2      1         836  138159.85
# 1  SACRAMENTO  Residential     3      1        1167  167541.46
# 2  SACRAMENTO  Residential     2      1         796  119095.12
# 3  SACRAMENTO  Residential     2      1         852  130904.95
# 4  SACRAMENTO  Residential     2      1         797  120266.19

# %%
df['Price'] # series - single col
# Out:
# 0      138159.85
# 1      167541.46
# 2      119095.12
# 3      130904.95
# 4      120266.19
#          ...
# 809    308248.47
# 810    212857.63
# 811    181746.98
# 812    245385.59
# 813    263355.13
# Name: Price, Length: 814, dtype: float64

# %%
df[['SquareFeet','Price']] # dataframe - more than one col
# Out:
#      SquareFeet      Price
# 0           836  138159.85
# 1          1167  167541.46
# 2           796  119095.12
# 3           852  130904.95
# 4           797  120266.19
# ..          ...        ...
# 809        2280  308248.47
# 810        1477  212857.63
# 811        1216  181746.98
# 812        1685  245385.59
# 813        1362  263355.13
#
# [814 rows x 2 columns]

# %% [markdown]
# # add a new col

# %%
df["price_per_ft"] = df['Price'] / df['SquareFeet']
df["price/ft"] = df['Price'] / df['SquareFeet']

# %%
df.head()
# Out:
#          City         Type  Beds  Baths  SquareFeet      Price  price_per_ft  \
# 0  SACRAMENTO  Residential     2      1         836  138159.85    165.262978
# 1  SACRAMENTO  Residential     3      1        1167  167541.46    143.565947
# 2  SACRAMENTO  Residential     2      1         796  119095.12    149.616985
# 3  SACRAMENTO  Residential     2      1         852  130904.95    153.644308
# 4  SACRAMENTO  Residential     2      1         797  120266.19    150.898607
#
#      price/ft
# 0  165.262978
# 1  143.565947
# 2  149.616985
# 3  153.644308
# 4  150.898607

# %% [markdown]
# # removing a col

# %%
df.drop(columns=['price/ft'], inplace=True) #inplace mean update the dataframe and wont show output

# %%
df.columns.tolist()
# Out:
# ['City', 'Type', 'Beds', 'Baths', 'SquareFeet', 'Price', 'price_per_ft']

# %% [markdown]
# # maths on columns(series)

# %%
df['Beds'].mean()
# Out:
# 3.2444717444717446

# %%
df['Beds'].sum()
# Out:
# 2641

# %%
df['City'].unique().tolist()
# Out:
# ['SACRAMENTO',
#  'RANCHO CORDOVA',
#  'RIO LINDA',
#  'CITRUS HEIGHTS',
#  'NORTH HIGHLANDS',
#  'ANTELOPE',
#  'ELK GROVE',
#  'ELVERTA',
#  'GALT',
#  'CARMICHAEL',
#  'ORANGEVALE',
#  'FOLSOM',
#  'MATHER',
#  'POLLOCK PINES',
#  'GOLD RIVER',
#  'RANCHO MURIETA',
#  'WILTON',
#  'GREENWOOD',
#  'FAIR OAKS',
#  'PLACERVILLE',
#  'MEADOW VISTA',
#  'ROSEVILLE',
#  'LINCOLN',
#  'CAMERON PARK',
#  'ROCKLIN',
#  'LOOMIS',
#  'AUBURN',
#  'EL DORADO HILLS',
#  'EL DORADO',
#  'PENRYN',
#  'GRANITE BAY',
#  'DIAMOND SPRINGS',
#  'COOL',
#  'WALNUT GROVE',
#  'SLOUGHHOUSE',
#  'WEST SACRAMENTO']

# %%
df['Type'].unique().tolist()
# Out:
# ['Residential', 'Condo', 'Multi-Family']

# %%
df.sort_values('price_per_ft',ascending=False,inplace=True)
df
# Out:
#                 City          Type  Beds  Baths  SquareFeet      Price  \
# 645           LOOMIS   Residential     4      2        1328  563850.89
# 480           PENRYN   Residential     3      2        1320  524117.00
# 291           LOOMIS   Residential     4      4        1624  601445.11
# 213      PLACERVILLE   Residential     2      1         948  318212.09
# 438           AUBURN  Multi-Family     2      2         960  275360.95
# ..               ...           ...   ...    ...         ...        ...
# 22   NORTH HIGHLANDS   Residential     4      2        1240  147789.79
# 33           ELVERTA   Residential     3      2        1116  131904.93
# 333          ELVERTA   Residential     4      2        1354  154599.18
# 170          ELVERTA   Residential     3      2        1080  121091.47
# 704      SLOUGHHOUSE   Residential     3      4        5822   11985.00
#
#      price_per_ft
# 645    424.586514
# 480    397.058333
# 291    370.347974
# 213    335.666762
# ...

# %%
df.head(25).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_7919aaec_33d1_11eb_aa69_10c37b9499e0row0_col2 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_7919aaec_33d1_11eb_aa69_10c37b9499e0row0_col3 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_7919aaec_33d1_11eb_aa69_10c37b9499e0row0_col4 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_7919aaec_33d1_11eb_aa69_10c37b9499e0row0_col5 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_7919aaec_33d1_11eb_aa69_10c37b9499e0row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7919aaec_33d1_11eb_aa69_10c37b9499e0row1_col2 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_7919aaec_33d1_11eb_aa69_10c37b9499e0row1_col3 {
#             background-color:  #b4c4df;
#             color:  #000000;
# ...

# %%
df.head(25).style.bar()
# Out:
# <style  type="text/css" >
#     #T_ae28acf9_33d1_11eb_935b_10c37b9499e0row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 66.7%, transparent 66.7%);
#         }    #T_ae28acf9_33d1_11eb_935b_10c37b9499e0row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.3%, transparent 33.3%);
#         }    #T_ae28acf9_33d1_11eb_935b_10c37b9499e0row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.9%, transparent 25.9%);
#         }    #T_ae28acf9_33d1_11eb_935b_10c37b9499e0row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 76.7%, transparent 76.7%);
#         }    #T_ae28acf9_33d1_11eb_935b_10c37b9499e0row0_col6 {
#             width:  10em;
#              height:  80%;
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.countplot(x='City',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## boolean filter in pandas

# %%
cityfilter = df['City'] == 'SACRAMENTO'

# %%
sacramentodf = df[cityfilter]

# %%
sacramentodf['Price'].plot(kind='hist',align='left')
plt.show()

# %%
df[df['City'] == 'ELK GROVE']['Price'].plot(kind='hist',align='left')
plt.title('ELK GROVE HOUSE PRICING')
plt.show()

# %% [markdown]
# # TASK -> BOOLEAN FILTER ON TYPE OF HOUSE

# %% [markdown]
# # grouping data for analysis

# %%
df
# Out:
#                 City          Type  Beds  Baths  SquareFeet      Price  \
# 645           LOOMIS   Residential     4      2        1328  563850.89
# 480           PENRYN   Residential     3      2        1320  524117.00
# 291           LOOMIS   Residential     4      4        1624  601445.11
# 213      PLACERVILLE   Residential     2      1         948  318212.09
# 438           AUBURN  Multi-Family     2      2         960  275360.95
# ..               ...           ...   ...    ...         ...        ...
# 22   NORTH HIGHLANDS   Residential     4      2        1240  147789.79
# 33           ELVERTA   Residential     3      2        1116  131904.93
# 333          ELVERTA   Residential     4      2        1354  154599.18
# 170          ELVERTA   Residential     3      2        1080  121091.47
# 704      SLOUGHHOUSE   Residential     3      4        5822   11985.00
#
#      price_per_ft
# 645    424.586514
# 480    397.058333
# 291    370.347974
# 213    335.666762
# ...

# %%
df.groupby('Type').mean()
# Out:
#                   Beds     Baths   SquareFeet          Price  price_per_ft
# Type
# Condo         1.904762  1.404762   977.690476  167483.561190    172.275894
# Multi-Family  4.461538  3.076923  2046.923077  286815.841538    147.074681
# Residential   3.297760  1.972332  1617.285903  242835.621199    152.574892

# %%
df.groupby('Type').mean()['price_per_ft'].plot(kind='pie',autopct='%.1f%%')
plt.ylabel('')
plt.show()
